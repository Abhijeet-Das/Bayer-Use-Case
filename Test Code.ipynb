# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pip install dask[dataframe]
# Out:
# ...
#      |████████████████████████████████| 134 kB 3.9 MB/s
# ...

# %%
from dask import dataframe as df1
dask_df = df1.read_csv('/content/gdrive/My Drive/Colab Notebooks/Bayer/PacakgingLineDataSet.csv', encoding = 'unicode_escape')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/dask/dataframe/__init__.py in <module>()
#      12     from .groupby import Aggregation
# ---> 13     from .io import (
#      14         from_array,
#
# /usr/local/lib/python3.7/dist-packages/dask/dataframe/io/__init__.py in <module>()
#      12 )
# ---> 13 from .csv import read_csv, to_csv, read_table, read_fwf
#      14 from .hdf import read_hdf, to_hdf
#
# /usr/local/lib/python3.7/dist-packages/dask/dataframe/io/csv.py in <module>()
#      20 # this import checks for the importability of fsspec
# ---> 21 from ...bytes import read_bytes, open_file, open_files
#      22 from ...delayed import delayed
#
# /usr/local/lib/python3.7/dist-packages/dask/bytes/__init__.py in <module>()
#       9     raise ImportError(
# ---> 10         "fsspec is required to use any file-system functionality."
# ...

# %%
dask_df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-22065cbf6c33> in <module>()
# ----> 1 dask_df.shape
#
# NameError: name 'dask_df' is not defined

# %%
dask_df.head(10)

# %%
df = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Bayer/PacakgingLineDataSet.csv', encoding = 'unicode_escape')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (620,621) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import pandas as pd
chunksize = 10 ** 8
for chunk in pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Bayer/PacakgingLineDataSet.csv', encoding = 'unicode_escape', chunksize=chunksize):
    process(chunk)

# %%
df = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Bayer/PacakgingLineDataSet.csv', encoding = 'unicode_escape', nrows=500000, low_memory=False)

# %%
temp = df.iloc[[0, -1]]
temp
# Out:
#                   Date_Time                ActivityName              Category  \
# 0       2020-06-08 20:13:58                 Undefiniert  2 Unplanned downtime
# 499999  2020-06-14 20:10:09  Undefiniert (Grund wählen)  2 Unplanned downtime
#
#         ProductionYN  \
# 0                  0
# 499999             0
#
#         GRZ_L09_02_Filler_APP_VarPersistent_VC_MD_955_Z_R_CP_BadTubesDisch_V  \
# 0                                                     967
# 499999                                                104
#
#         GRZ_L09_07_Case_Packer_CrtClos_FlapfTR_cl_V  \
# 0                                                 0
# 499999                                            0
#
#         GRZ_L09_04_Cartoner_SX_V0102_00_ProductInsertedCompl_VC_MD_102_Z_A_CD_ProdNotInserted_V  \
# 0                                                    2934
# 499999                                               2981
#
# ...

# %%
temp = df.iloc[[0, -1]]
temp
# Out:
#                   Date_Time                ActivityName              Category  \
# 0       2020-06-08 20:13:58                 Undefiniert  2 Unplanned downtime
# 549999  2020-06-15 10:27:59  Undefiniert (Grund wählen)  2 Unplanned downtime
#
#         ProductionYN  \
# 0                  0
# 549999             0
#
#         GRZ_L09_02_Filler_APP_VarPersistent_VC_MD_955_Z_R_CP_BadTubesDisch_V  \
# 0                                                     967
# 549999                                                147
#
#         GRZ_L09_07_Case_Packer_CrtClos_FlapfTR_cl_V  \
# 0                                                 0
# 549999                                            0
#
#         GRZ_L09_04_Cartoner_SX_V0102_00_ProductInsertedCompl_VC_MD_102_Z_A_CD_ProdNotInserted_V  \
# 0                                                    2934
# 549999                                               2985
#
# ...

# %%
testDf = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Bayer/PacakgingLineDataSet.csv', encoding = 'unicode_escape',skiprows=[i for i in range(1,500000)], low_memory=False)

# %%
temp = testDf.iloc[[0, -1]]
temp
# Out:
#                   Date_Time                ActivityName              Category  \
# 0       2020-06-14 20:10:09  Undefiniert (Grund wählen)  2 Unplanned downtime
# 261537  2020-06-17 23:59:59                 Undefiniert  2 Unplanned downtime
#
#         ProductionYN  \
# 0                  0
# 261537             0
#
#         GRZ_L09_02_Filler_APP_VarPersistent_VC_MD_955_Z_R_CP_BadTubesDisch_V  \
# 0                                                     104
# 261537                                               4132
#
#         GRZ_L09_07_Case_Packer_CrtClos_FlapfTR_cl_V  \
# 0                                                 0
# 261537                                            0
#
#         GRZ_L09_04_Cartoner_SX_V0102_00_ProductInsertedCompl_VC_MD_102_Z_A_CD_ProdNotInserted_V  \
# 0                                                    2981
# 261537                                               3078
#
# ...

# %%
testDf = pd.read_csv('/content/gdrive/My Drive/Colab Notebooks/Bayer/PacakgingLineDataSet.csv', encoding = 'unicode_escape', skiprows = 761537 - 1000,index_col=0)

# %%
testDf.shape
# Out:
# (1000, 669)

# %%
temp = testDf.iloc[[0, -1]]
temp
# Out:
#                      Undefiniert  2 Unplanned downtime  0  4132  0.1  3078  \
# 2020-06-17 23:43:19
# 2020-06-17 23:43:20  Undefiniert  2 Unplanned downtime  0  4132    0  3078
# 2020-06-17 23:59:59  Undefiniert  2 Unplanned downtime  0  4132    0  3078
#
#                      0.2  2.18  0.3  73  ...  0.292  0.293  0.294  0.295  \
# 2020-06-17 23:43:19                      ...
# 2020-06-17 23:43:20    0  2.18    0  73  ...      0      0      0      0
# 2020-06-17 23:59:59    0  2.23    0  73  ...      0      0      0      0
#
#                      0.296  0.297  1.79  1.80  0.298  2020-06-17 23:43:19.1
# 2020-06-17 23:43:19
# 2020-06-17 23:43:20      0      0     1     1      0    2020-06-17 23:43:20
# 2020-06-17 23:59:59      0      0     1     1      0    2020-06-17 23:59:59
#
# [2 rows x 669 columns]

# %%
df.head()
# Out:
#              Date_Time ActivityName              Category  ProductionYN  \
# 0  2020-06-08 20:13:58  Undefiniert  2 Unplanned downtime             0
# 1  2020-06-08 20:13:59  Undefiniert  2 Unplanned downtime             0
# 2  2020-06-08 20:14:00  Undefiniert  2 Unplanned downtime             0
# 3  2020-06-08 20:14:01  Undefiniert  2 Unplanned downtime             0
# 4  2020-06-08 20:14:02  Undefiniert  2 Unplanned downtime             0
#
#    GRZ_L09_02_Filler_APP_VarPersistent_VC_MD_955_Z_R_CP_BadTubesDisch_V  \
# 0                                                967
# 1                                                967
# 2                                                967
# 3                                                967
# 4                                                967
#
#    GRZ_L09_07_Case_Packer_CrtClos_FlapfTR_cl_V  \
# 0                                            0
# 1                                            0
# ...

# %%
# iterating the columns
count = 0
for col in df.columns:
    print(col)
    count = count +1
print(count)
# Out:
# Date_Time
# ActivityName
# Category
# ProductionYN
# GRZ_L09_02_Filler_APP_VarPersistent_VC_MD_955_Z_R_CP_BadTubesDisch_V
# GRZ_L09_07_Case_Packer_CrtClos_FlapfTR_cl_V
# GRZ_L09_04_Cartoner_SX_V0102_00_ProductInsertedCompl_VC_MD_102_Z_A_CD_ProdNotInserted_V
# GRZ_L09_04_Cartoner_SX_V0102_00_ProductInsertedCompl_VC_MX_102_MF_ProdNotInsert_V
# GRZ_L09_01_Blistering_PLC_Modules__Default__Global_PV_tGlCoolCirSW_tCoolCir_tCoolCir_3__fFlowRate_l_min_V
# GRZ_L09_07_Case_Packer_CrtClos_FlapfTL_cl_V
# GRZ_L09_04_Cartoner_SX_V0102_00_ProductInsertedCompl_VC_MD_102_Z_R_CD_ProdNotInserted_V
# GRZ_L09_01_Blistering_PLC_Modules__Default__Global_PV_tGlCoolCirSW_tCoolCir_tCoolCir_1__fFlowRate_l_min_V
# GRZ_L09_04_Cartoner_SX_V3420_00_CollectingChain_VC_MX_3420_MS_ProductCollision_V
# GRZ_L09_06__Bundler_Application_SeaF_HMI_SeaF_V_r_PosAct_V
# GRZ_L09_06__Bundler_Application_SeaJ_HMI_SeaJ_V_r_SealTempAct_le_V
# GRZ_L09_02_Filler_APP_V2200_00_BoxInfeed_VC_MX_2200_T_S_BoxInfeed_V
# ...

# %%
pip install datatable
# Out:
# ...
#      |████████████████████████████████| 96.9 MB 109 kB/s
# ...

# %%
import datatable as dt
from datatable import (dt, f, by, ifelse, update, sort,
                       count, min, max, mean, sum, rowsum)
dt_df = dt.fread('/content/gdrive/My Drive/Colab Notebooks/Bayer/PacakgingLineDataSet.csv')
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# ...

# %%
dt_df
# Out:
# <Frame#7f30c11df510 761537x670>
